# %%
import pandas as pd
import numpy as np
import pickle

# %%
fdir = 'data/'
fname = 'Sputnik DAO Proposals.xlsx'
newfname = 'Sputnik DAO Proposals Cleaned.xlsx'
df_dao_proposals = pd.read_excel(fdir+fname,sheet_name=None)
for daoname in df_dao_proposals.keys():
    if daoname=='WORKSPACE': # this is not a dao, so skip it
        continue
    df = df_dao_proposals[daoname]
    df.columns = df.columns.str.replace(' ', '_').str.lower() # clean column names to avoid pandas key error
    # transform the amount to be in the unit of near
    if 'kind__amount' in df.keys():
        df['kind__amount'] = pd.to_numeric(df['kind__amount'],errors = 'coerce')/(10**24)
        df.rename({'kind__amount':'amount_(near)'})
        
    else:
        df['amount_(near)'] = pd.to_numeric(df['amount_(near)'],errors = 'coerce')
    # also, standardize column names
    if 'target' not in df.columns:
        df.columns = df.columns.str.replace('.*recipient.*', 'target',regex=True)
    # standardize the time stamps
    df['vote_period_end'] =pd.to_datetime(df['vote_period_end'])
    
    df.to_excel(fdir+newfname,sheet_name=daoname)

df_grants
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5cb74836c195> in <module>
#      22     df.to_excel(fdir+newfname,sheet_name=daoname)
#      23
# ---> 24 df_grants = pd.DataFrame(df_grants).sort_values(by='grants')
#      25 df_grants
#
# NameError: name 'df_grants' is not defined

# %%
df
# Out:
#       status               proposer                      target  \
# 0    Success             mxjxn.near                  mxjxn.near
# 1    Success            codame.near              starpause.near
# 2    Success             chloe.near  createbase.sputnikdao.near
# 3    Success      microchipgnu.near                barbara.near
# 4    Success      weeblespruce.near           weeblespruce.near
# ..       ...                    ...                         ...
# 486  Success            vandal.near                 vandal.near
# 487  Success             tolga.near                  tolga.near
# 488  Success        aqualift22.near             aqualift22.near
# 489  Success    thephilosopher.near         thephilosopher.near
# 490     Vote  raizverticalfarm.near       raizverticalfarm.near
#
#                                            description kind__type  kind__bond  \
# 0    testing sending 10 NEAR to arts.sputnikdao.nea...     Payout         NaN
# 1    Article linking to all of the NEAR talks from ...     Payout         NaN
# 2    Making a video explaining how to use Sputnik D...     Payout         NaN
# 3    Making a micropayment in WebXR using the NEAR ...     Payout         NaN
# 4    I'll explain Near to my dog and post it on twi...     Payout         NaN
# ..                                                 ...        ...         ...
# 486  Ravespace DJ set recording for Vandal ---https...     Payout         NaN
# 487  Dj set & Studio hire fees for Ravespace.club -...     Payout         NaN
# 488  Payout for Reddit moderator of October for Min...     Payout         NaN
# 489  Resources fo onboard 50 people on mintbase-nea...     Payout         NaN
# 490  Fund request to open mintbase store. ---https:...     Payout         NaN
#
#     kind__purpose  kind__amount               vote_period_end  vote_yes  ...  \
# 0             NaN  1.000000e+25 2021-02-19 16:37:29.684098560       2.0  ...
# 1             NaN  1.000000e+25 2021-02-19 17:16:35.774045184       2.0  ...
# 2             NaN  1.000000e+25 2021-02-22 19:52:57.994595328       2.0  ...
# 3             NaN  1.000000e+25 2021-02-23 10:59:46.919933952       2.0  ...
# 4             NaN  1.000000e+25 2021-02-24 14:00:22.137564416       2.0  ...
# ..            ...           ...                           ...       ...  ...
# 486           NaN  1.900000e+25 2021-11-18 12:30:15.983239680       3.0  ...
# 487           NaN  3.300000e+25 2021-11-18 13:51:32.289871104       3.0  ...
# 488           NaN  5.000000e+24 2021-11-18 14:09:51.485325568       3.0  ...
# 489           NaN  1.750000e+26 2021-11-19 16:43:52.976030208       3.0  ...
# 490           NaN  6.500000e+24 2021-11-23 20:08:36.384798976       0.0  ...
#
#      votes__monikablockdiver.near votes__reginanogueira.near votes__nate.near  \
# 0                             NaN                        NaN              NaN
# 1                             NaN                        NaN              NaN
# 2                             NaN                        NaN              NaN
# 3                             NaN                        NaN              NaN
# 4                             NaN                        NaN              NaN
# ..                            ...                        ...              ...
# 486                           NaN                        Yes              NaN
# 487                           NaN                        Yes              NaN
# 488                           Yes                        Yes              NaN
# 489                           Yes                        Yes              NaN
# 490                           NaN                        NaN              NaN
#
#     votes__carolin.near votes__mariamneu.near votes__sparrow.near  \
# 0                   NaN                   NaN                 NaN
# 1                   Yes                   NaN                 NaN
# 2                   Yes                   NaN                 NaN
# 3                   NaN                   NaN                 NaN
# 4                   Yes                   NaN                 NaN
# ..                  ...                   ...                 ...
# 486                 Yes                   Yes                 NaN
# 487                 Yes                   Yes                 NaN
# 488                 NaN                   Yes                 NaN
# 489                 NaN                   Yes                 NaN
# 490                 NaN                   NaN                 NaN
#
#     votes__chloethedev.near votes__len.near votes__createbase.near  \
# 0                       Yes             Yes                    NaN
# 1                       Yes             NaN                    NaN
# 2                       Yes             NaN                    NaN
# 3                       Yes             Yes                    NaN
# 4                       Yes             NaN                    NaN
# ..                      ...             ...                    ...
# 486                     NaN             NaN                    NaN
# 487                     NaN             NaN                    NaN
# 488                     NaN             NaN                    NaN
# 489                     NaN             NaN                    NaN
# 490                     NaN             NaN                    NaN
#
#     amount_(near)
# 0            10.0
# 1            10.0
# 2            10.0
# 3            10.0
# 4            10.0
# ..            ...
# 486          19.0
# 487          33.0
# 488           5.0
# 489         175.0
# 490           6.5
#
# [491 rows x 22 columns]
